# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/data/commonvoice/cv-corpus-9.0-2022-04-27/de/validated.tsv", sep="\t").dropna(subset=['sentence'])

# %%
len(df)
# Out:
# 764817

# %%
df
# Out:
#                                                 client_id  \
# 0       0052c07533a6976233ad5926d950b523002c4d8cdd9ae8...
# 1       00aa59ff387a07bf1c056cccd6715b3c764201f51092c3...
# 2       02274179aeff73e1e7897ed6fec2355af2cd6e5410e3c6...
# 3       02650022b4a4266846057d97ae4d81da8af9e09e2a4bb1...
# 4       02786062ec85038ffeed4c38ed7b31d3aa8e6439817fb1...
# ...                                                   ...
# 765785  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 765786  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 765787  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 765788  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 765789  372293e65cdab88771e028a4351651ab2eff64438ddafc...
#
#                                 path  \
# 0       common_voice_de_17922420.mp3
# 1       common_voice_de_27060918.mp3
# 2       common_voice_de_19728810.mp3
# 3       common_voice_de_19156087.mp3
# 4       common_voice_de_27395829.mp3
# ...

# %%
df
# Out:
#                                                 client_id  \
# 0       0052c07533a6976233ad5926d950b523002c4d8cdd9ae8...
# 1       00aa59ff387a07bf1c056cccd6715b3c764201f51092c3...
# 2       02274179aeff73e1e7897ed6fec2355af2cd6e5410e3c6...
# 3       02650022b4a4266846057d97ae4d81da8af9e09e2a4bb1...
# 4       02786062ec85038ffeed4c38ed7b31d3aa8e6439817fb1...
# ...                                                   ...
# 765785  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 765786  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 765787  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 765788  372293e65cdab88771e028a4351651ab2eff64438ddafc...
# 765789  372293e65cdab88771e028a4351651ab2eff64438ddafc...
#
#                                 path  \
# 0       common_voice_de_17922420.mp3
# 1       common_voice_de_27060918.mp3
# 2       common_voice_de_19728810.mp3
# 3       common_voice_de_19156087.mp3
# 4       common_voice_de_27395829.mp3
# ...

# %%
df[df["path"]=="common_voice_de_22137448.mp3"].dropna()
# Out:
# Empty DataFrame
# Columns: [client_id, path, sentence, up_votes, down_votes, age, gender, accents, locale, segment]
# Index: []

# %%
df[df["sentence"]==np.nan]
# Out:
# Empty DataFrame
# Columns: [client_id, path, sentence, up_votes, down_votes, age, gender, accents, locale, segment]
# Index: []
